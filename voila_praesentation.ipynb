# %%
from traitlets.config.manager import BaseJSONConfigManager
from pathlib import Path
path = Path.home() / ".jupyter" / "nbconfig"
cm = BaseJSONConfigManager(config_dir=str(path))
cm.update(
    "rise",
    {
        "theme": "night",
        "transition": "zoom",
        "start_slideshow_at": "beginning",
        "footer" : "<h2>Fortgeschrittene Programmierung | Steffen & Lucas</h2>",
        "enable_chalkboard": "true",
        "scroll" : "true"
     }
)
# Out:
# {'theme': 'night',
#  'transition': 'zoom',
#  'start_slideshow_at': 'beginning',
#  'overlay': "<div class='myfooter'><h2>Fortgeschrittene Programmierung | Steffen Weifenbach & Lucas Wätzig</h2></div>",
#  'enable_chalkboard': 'true',
#  'scroll': 'true',
#  'footer': '<h2>Fortgeschrittene Programmierung | Steffen & Lucas</h2>'}

# %% [markdown]
# # VOILA

# %% [markdown]
# ## TABLE OF CONTENT:
# ### 1. General information
# ### 2. How to a create website using voila
# ### 3. Example notebooks
# ### 4. Task for you

# %% [markdown]
# ## GENERAL INFORMATION

# %% [markdown]
# ### What does voila do?
# voila turns your jupyter notebook into a standalone website!

# %% [markdown]
# ## How to install

# %% [markdown]
# using conda: mamba install -c conda-forge voila
#
# using pip: pip install voila

# %% [markdown]
# ### Usage
# you can either use the add-on in jupyter notebook:
# ![image.png](attachment:image.png)
#
# or run: "voila {example.ipynb}" in you command shell to execute one specific notebook
# ![image-2.png](attachment:image-2.png)
#
# if you want to observe a directory, just run voila in h
